# %%
# The match statement in Python, introduced in Python 3.10, is a powerful feature for pattern matching.
# # It allows you to match values against patterns and execute code based on the match.

# %%
Poem = input('give the poem:')
counter = 0
for letter in Poem:
    if letter == 'e' or letter == 'E':
        counter = counter+1
# if letter == 'E':
#     counter = counter+1
#     print(counter)
        
            
        # counter = counter+1
print(counter)
    

#     counter = counter+1
# print(counter)
# Out:
# give the poem: This is the End of THE MONTH
# 3
