# %%
count = 5
while (count > 1):  # Condition: Loop as long as 'count' is greater than 1
    print(count)
    count = count - 1 # Decrementing 'count' by 1
# Out:
# 5
# 4
# 3
# 2

# %%
# do while loop is not in python but available in other languages ex in C++
# how to emulate it in do while in python.
