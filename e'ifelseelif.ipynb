# %%
no = int(input('give the first no'))
if (no < 0):
    print(int(no),'the given no is negative')
elif (no == 0):
    print(int(no),'the no is neither positive nor negative its zero')
else:
    print(int(no),'the no is positive')
# Out:
# give the first no 35
# 35 the no is positive

# %%
a = float(input('give the first no:'))
if (float(a) % 2 == 0): 
    print('Even')
else: 
    print('Odd')
# Out:
# give the first no: 23.4
# Odd

# %%
a = float(input('give the first no'))
b = a%2
print('the result is',b)
# Out:
# give the first no 23.4
# the result is 1.3999999999999986
