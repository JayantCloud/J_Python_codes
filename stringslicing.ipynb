# %%
name = "hi this is learning of slicing in strings"
print(name[0:7])
# Out:
# hi this

# %%
#we can find the length of string using len() function.

# %%
Function = "hi this is learning of python"
print(len(Function))
#this also counts spaces as length
# Out:
# 29

# %%
phone = "samsungS23"
print(phone[:5])
# Out:
# samsu

# %%
phone = "samsungS23"
print(phone[0:-5])
# Out:
# samsu

# %%
#we use square brackets for slicing of strings

# %%
# strings are immutable
# to comment out snything we have to use ctrl + forward slash

# %%
a = 'what shall i write in it'
print(a.upper())
# Out:
# WHAT SHALL I WRITE IN IT

# %%
a = 'HI THIS IS SECOND DAY OF learning to make upper and lower case in python'
print(a.lower())
# Out:
# hi this is second day of learning to make upper and lower case in python

# %%
A = '!!Jayant@@@@!!!!'
print(A.rstrip('@'))
print(A.rstrip('!'))
#rstrip can only remove the trailing characters not the begining ones
# Out:
# !!Jayant@@@@!!!!
# !!Jayant@@@@

# %%
A = 'Jayant'
print(A.replace("Jayant","ABC"))
# Out:
# ABC
