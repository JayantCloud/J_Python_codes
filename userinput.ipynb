# %%
a = input("x")
b = input("y")
c = a+b
print(c)
# Out:
# x 3
# y 34
# 334

# %%
a = input("give the first no")
b = input("give the second no")
c = int(a) + int(b)
print (c)
# Out:
# give the first no 12
# give the second no 123
# 135
