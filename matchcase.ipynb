# %%
print('hi')
# Out:
# hi

# %%
x = int(input("give the number:"))
match x:
      case 0:
           print("x is zero")
      case _  if x<10:
                print("x is unit digit")
      case _ if x >= 10:  
                print("x is two digit")
# Out:
# give the number: 100
# x is two digit
