# %%
def sum_num(x,y):
    '''its the sum of two numbers only'''
    z = x+y
    return z
x = 5
y = 6
print(sum_num(x,y))
# Out:
# 11

# %%
def si(p,r,t):
    '''trying to calculate the si on python'''
    z = (p*r*t)/100
    return z
p = int(input())
r = int(input())
t = int(input())
print("the si is:",si(p,r,t))
# Out:
#  12
#  3
#  4
# the si is: 1.44
