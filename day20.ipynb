# %% [markdown]
# # Functions
# **Abstraction**.
#
# Functions in Python encapsulate logic, allowing you to reuse and organize code efficiently—hiding complexity behind a simple interface.

# %%
def CalculateMean(a,b):
    mean = (a+b)/2
    print(mean)
z = int(input("how many digits do you have"))
if(z == 2): 
    a = int(input("give the first number"))
    b = int(input("give the second number"))
    CalculateMean(a,b)
   # print("the given mean")
else:
    print("please take 2 numbers only for now:")
# Out:
# how many digits do you have 2
# give the first number 23
# give the second number 45
# 34.0

# %% [markdown]
# ### another code

# %%
def CalculateMean(a,b):
    mean = (a+b)/2
    print(mean)
def isgreater (a,b):
    if (a>b):
        print("First number is greater")
    else:
        print("Second number is greater")

a = int(input("give the first number"))
b = int(input("give the second one"))
isgreater(a,b)
CalculateMean(a,b)
# Out:
# give the first number 32
# give the second one 42
# Second number is greater
# 37.0

# %% [markdown]
#  **there are two types of  functions**
#
#  -Built in (min(),max(),sum())
#
#  -user defined which we as programmer defines it as done above
