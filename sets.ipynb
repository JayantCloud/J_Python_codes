# %% [markdown]
# In Python, a set is a built-in data type that represents an unordered collection of unique elements.
#
# 🔑 Key Characteristics of Sets
# Uniqueness: No duplicate elements are allowed. If you try to add a duplicate, Python ignores it.
#
# Unordered: Elements have no defined order, so indexing and slicing don’t work.
#
# Mutable: You can add or remove elements after creation.
#
# Efficient operations: Sets are optimized for membership tests (in keyword) and mathematical set operations.

# %%
m = {1,23,43,65,12,898,23}
print(m)
type(m)
# Out:
# {65, 898, 1, 23, 43, 12}
# set

# %%
n = {}
type(n)
# Out:
# dict

# %%
k = set()

type(k)
# Out:
# set
