# %%
dict = { "hast":"human",
         "table":"utensils"}
print(dict["hast"])
# Out:
# human

# %%
dict = { "hast":"human",
         "table":"utensils"}
print(dict.get("hast3"))
# Out:
# None

# %%
inventory = {
    "gold": 500,
    "potions": 3,
    "sword": "Steel Blade"
}
# for key, value in inventory.items():
#     print({key} , {value})

print({key},{value})
# Out:
# {'sword'} {'Steel Blade'}

# %%
inventory = {
    "gold": 500,
    "potions": 3,
    "sword": "Steel Blade"
}
print(key)
print(inventory["potions"])
del (inventory["gold"])
print(inventory["gold"])
# Out:
# sword
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 9
#       7 print(inventory["potions"])
#       8 del (inventory["gold"])
# ----> 9 print(inventory["gold"])
#
# KeyError: 'gold'
