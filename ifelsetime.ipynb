# %%
import time
timestamp = time.strftime('%H:%M:%S')
print(timestamp)
# Out:
# 12:48:24

# %%
import time
timestamp = time.strftime('%H:%M:%S')
print(timestamp)
# timestamp = (input('time'))
if (timestamp < '12:00:00'):
    print('good morning')
elif ( timestamp == '12:00:00'):
    print('good noon')
else:
    print('good evening')
# Out:
# 12:48:46
# good evening

# %%
import time
timestamp = time.strftime('%H:%M:%S')
print(timestamp)
timestamp = (input('time'))
if (timestamp < '12:00:00'):
    print('Good Morning')
# elif ( timestamp == '12:00:00'):
    # print('good noon')
else:
    if(timestamp>='12:00:00' and timestamp<='16:30:00'):
        print('Good Noon')
    else:
        print('good Evening')
# Out:
# 12:48:52
# time 02:50:00
# Good Morning

# %%
import time
timestamp = time.strftime('%H:%M:%S')
print(timestamp)
timestamp = (input('time'))
ampm = input('amorpm')
if (timestamp < '12:00:00'):
    if(am/pm == 'am'):
        print('Good Morning')
if(am/pm == 'pm'):
    print('Good Evening')       
else:
    print('the given time format is wrong')
   
    # if(ampm == 'pm'):
    #         print('Good Evening')
    # else:
         
        
# else:
#     if(ampm == 'pm'):
#          print('Good Evening')
#     else:
#         print('the given time is wrong')
       
    # print('Good Evening')
    

             

        # if (timestamp < '12:00:00'):
         # if(ampm == 'pm'):
# Out:
# 12:58:57
# time 02:20:00
# amorpm am
# Good Morning
# the given time format is wrong
