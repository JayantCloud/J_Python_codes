# %%
apple = 'he said he is fighter, \'now this is contradictory'
print(apple)
# Out:
# he said he is fighter, 'now this is contradictory

# %%
#learning new concepts of strings

# %%
new ='''anything written in 
tripple inverted commas will be considered as
strings no matter how many lines you break'''
print(new)
# Out:
# anything written in
# tripple inverted commas will be considered as
# strings no matter how many lines you break

# %%
learn='''in tripple inverted commas things become string'''
print(learn)
# Out:
# in tripple inverted commas things become string
