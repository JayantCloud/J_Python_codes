# %%
# Indentation in Python is crucial because it defines the structure and flow of your code.
# Unlike many other programming languages that use braces {} to delimit blocks of code,
# Python uses indentation to indicate a block of code. This makes the code more readable and enforces a clean, consistent style.

# %%
basket = input('give your basket price:')
budget =input('give your budget')
if (basket <= budget):
    print('you can purchase this')
else:
    print('please bring $',int(basket)-int(budget))
# Out:
# give your basket price: 23
# give your budget 54
# you can purchase this
