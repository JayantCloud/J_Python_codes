# %% [markdown]
# **Break and continue statement in the python**
#
#
# *date 26th- dec-2025*

# %% [markdown]
# the break statement enables the program to skip over the part of code i.e the break statement terminates the very loop it lies within

# %%
for i in range(10):
    print(" 5 times",i+1 , "=", 5 * (i+1))
    if(i == 5):
        break
# Out:
#  5 times 1 = 5
#  5 times 2 = 10
#  5 times 3 = 15
#  5 times 4 = 20
#  5 times 5 = 25
#  5 times 6 = 30

# %% [markdown]
# # continue statement
# the continue statement skips the rest of loop statement and causes the next iteration to occur.

# %%
for i in range(10):
    if(i==6):
        print("skipped the iteration")
        continue
    print(" 6 times", i+1, 6*(i+1))
# Out:
#  6 times 1 6
#  6 times 2 12
#  6 times 3 18
#  6 times 4 24
#  6 times 5 30
#  6 times 6 36
# skipped the iteration
#  6 times 8 48
#  6 times 9 54
#  6 times 10 60

# %%
# Out:
# Step 1: Removing page duplicates...
# Step 2: Grouping sessions by user...
# Step 3: Removing specified pages...
#
# Final cleaned dataset:
#    user_id                                    grouped_journey  \
# 0     1516  Homepage-Log in-Other-Other-Sign up-Log in-Log...
# 1     3395  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2    10107  Homepage-Homepage-Career tracks-Sign up-Log in...
# 3    11145  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4    12400  Homepage-Career tracks-Sign up-Log in-Other-Ca...
# 5    13082  Checkout-Checkout-Checkout-Homepage-Sign up-Lo...
# 6    14415  Pricing-Sign up-Homepage-Log in-Log in-Checkou...
# 7    15630  Log in-Log in-Log in-Log in-Log in-Checkout-Ch...
# 8    16589  Homepage-Career tracks-Pricing-Sign up-Homepag...
# 9    19458  Homepage-Sign up-Log in-Log in-Log in-Other-Ho...
#
#   subscription_type                                      final_journey
# 0            Annual  Homepage-Log in-Other-Other-Sign up-Log in-Log...
# 1            Annual  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2            Annual  Homepage-Homepage-Career tracks-Sign up-Log in...
# 3           Monthly  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4           Monthly  Homepage-Career tracks-Sign up-Log in-Other-Ca...
# 5           Monthly  Checkout-Checkout-Checkout-Homepage-Sign up-Lo...
# 6           Monthly  Pricing-Sign up-Homepage-Log in-Log in-Checkou...
# 7            Annual  Log in-Log in-Log in-Log in-Log in-Checkout-Ch...
# 8         Quarterly  Homepage-Career tracks-Pricing-Sign up-Homepag...
# 9            Annual  Homepage-Sign up-Log in-Log in-Log in-Other-Ho...
# C:\Users\jayan\AppData\Local\Temp\ipykernel_14532\1138173740.py:39: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped = df.groupby(group_column).apply(combine_journeys).reset_index()

# %%
# Out:
# Cleaned dataset saved as: user_journey_cleaned.csv
#
# Dataset Statistics:
# Total users: 1350
# Subscription types:
# subscription_type
# Annual       931
# Monthly      376
# Quarterly     43
# Name: count, dtype: int64
#
# Average journey length: 11.62 pages
# Max journey length: 239 pages
# Min journey length: 1 pages

# %%
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_14532\1138173740.py:39: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped = df.groupby(group_column).apply(combine_journeys).reset_index()
# Configuration 1 (first 5 sessions, remove 'Log in'):
#    user_id                                    grouped_journey  \
# 0     1516  Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
# 1     3395  Other-Other-Pricing-Sign up-Sign up-Log in-Log...
# 2    10107  Homepage-Homepage-Homepage-Homepage-Homepage-H...
#
#   subscription_type                                      final_journey
# 0            Annual  Homepage-Other-Other-Sign up-Sign up-Sign up-S...
# 1            Annual  Other-Other-Pricing-Sign up-Sign up-Homepage-P...
# 2            Annual  Homepage-Homepage-Homepage-Homepage-Homepage-H...
# Average journey length: 31.30
#
# Configuration 2 (all sessions, remove multiple pages):
#    user_id                                    grouped_journey  \
# 0     1516  Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
# 1     3395  Other-Other-Pricing-Sign up-Sign up-Log in-Log...
# 2    10107  Homepage-Homepage-Homepage-Homepage-Homepage-H...
#
#   subscription_type                                      final_journey
# 0            Annual  Sign up-Sign up-Sign up-Sign up-Sign up-Checko...
# 1            Annual  Pricing-Sign up-Sign up-Pricing-Pricing-Checko...
# 2            Annual  Career tracks-Career tracks-Career tracks-Care...
# Average journey length: 43.22
# C:\Users\jayan\AppData\Local\Temp\ipykernel_14532\1138173740.py:39: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped = df.groupby(group_column).apply(combine_journeys).reset_index()
